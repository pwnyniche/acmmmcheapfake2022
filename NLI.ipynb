# %%
from transformers import pipeline
import pandas as pd
from tqdm import tqdm
# Out:
# 2022-06-19 13:33:06.427439: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-06-19 13:33:06.427484: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
classifier = pipeline("text-classification", model = "microsoft/deberta-xlarge-mnli",framework='pt')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/envs/acmmm/lib/python3.7/site-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#     904         try:
# --> 905             return importlib.import_module("." + module_name, self.__name__)
#     906         except Exception as e:
#
# ~/anaconda3/envs/acmmm/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~/anaconda3/envs/acmmm/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/envs/acmmm/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/envs/acmmm/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ...
